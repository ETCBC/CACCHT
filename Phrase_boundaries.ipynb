# %% [markdown]
# # Find phrase boundaries in BH

# %% [markdown]
# The model in this notebook is designed to find clause and phrase boundaries in chunks of BH text, based on the division in phrases in the ETCBC database.
# The model assumes that the text has been analyzed on word level already.
#
# Each input chunk consists of 20 words. Each word is represented by its part of speech. For instance, a typical chunk has the following structure (the example shows the first 20 words of the book of Genesis):
#
# ['prep', 'subs', 'verb', 'subs', 'prep', 'art', 'subs', 'conj', 'prep', 'art', 'subs', 'conj', 'art', 'subs', 'verb', 'subs',  'conj',  'subs','conj', 'subs']
#
# The corresponding output is:
#
# ['\t', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'x', 'x', 'x', 'x', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'p', 'x', 'x', 'x', 'p', 'x', 'p', 'x', 'p', '\n']
#
# Here every 'x' represents a word in the input sequence, and 'p' marks the end of a phrase. '\t' and '\n' are start and stop symbols.
#
# In the following input chunk we have moved forward one word:
#
# Input:
#
#  ['subs', 'verb', 'subs', 'prep', 'art', 'subs', 'conj', 'prep', 'art', 'subs', 'conj', 'art', 'subs', 'verb', 'subs', 'conj', 'subs', 'conj', 'subs', 'prep']
#
# Output:
#
# ['\t', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'x', 'x', 'x', 'x', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'p', 'x', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', '\n']

# %%
from keras.models import Model
from keras.layers import Input, LSTM, Dense
import numpy as np

from sklearn.utils import shuffle

# %%
from tf.app import use
A = use('bhsa', hoist=globals())
#A.displaySetup(extraFeatures='g_cons')
# Out:
# TF app is up-to-date.
# Using annotation/app-bhsa commit 7f353d587f4befb6efe1742831e28f301d2b3cea (=latest)
#   in C:\Users\geitb/text-fabric-data/__apps__/bhsa.
# Using etcbc/bhsa/tf - c r1.5 in C:\Users\geitb/text-fabric-data
# Using etcbc/phono/tf - c r1.2 in C:\Users\geitb/text-fabric-data
# Using etcbc/parallels/tf - c r1.2 in C:\Users\geitb/text-fabric-data
# **Documentation:** <a target="_blank" href="https://etcbc.github.io/bhsa" title="provenance of BHSA = Biblia Hebraica Stuttgartensia Amstelodamensis">BHSA</a> <a target="_blank" href="https://annotation.github.io/text-fabric/Writing/Hebrew" title="('Hebrew characters and transcriptions',)">Character table</a> <a target="_blank" href="https://etcbc.github.io/bhsa/features/hebrew/c/0_home.html" title="BHSA feature documentation">Feature docs</a> <a target="_blank" href="https://github.com/annotation/app-bhsa" title="bhsa API documentation">bhsa API</a> <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Fabric/" title="text-fabric-api">Text-Fabric API 7.3.15</a> <a target="_blank" href="https://annotation.github.io/text-fabric/Use/Search/" title="Search Templates Introduction and Reference">Search Reference</a>
# <details open><summary><b>Loaded features</b>:</summary>
# <p><b>BHSA = Biblia Hebraica Stuttgartensia Amstelodamensis</b>: <a target="_blank" href="https://etcbc.github.io/bhsa/features/hebrew/c/book.html" title="C:\Users\geitb/text-fabric-data/etcbc/bhsa/tf/c\book.tf">book</a>  <a target="_blank" href="https://etcbc.github.io/bhsa/features/hebrew/c/book@ll.html" title="C:\Users\geitb/text-fabric-data/etcbc/bhsa/tf/c\book@am.tf">book@ll</a>  <a target="_blank" href="https://etcbc.github.io/bhsa/features/hebrew/c/chapter.html" title="C:\Users\geitb/text-fabric-data/etcbc/bhsa/tf/c\chapter.tf">chapter</a>  <a target="_blank" href="https://etcbc.github.io/bhsa/features/hebrew/c/code.html" title="C:\Users\geitb/text-fabric-data/etcbc/bhsa/tf/c\code.tf">code</a>  <a target="_blank" href="https://etcbc.github.io/bhsa/features/hebrew/c/det.html" title="C:\Users\geitb/text-fabric-data/etcbc/bhsa/tf/c\det.tf">det</a>  <a target="_blank" href="https://etcbc.github.io/bhsa/features/hebrew/c/freq_lex.html" title="C:\Users\geitb/text-fabric-data/etcbc/bhsa/tf/c\freq_lex.tf">freq_lex</a>  <a target="_blank" href="https://etcbc.github.io/bhsa/features/hebrew/c/function.html" title="C:\Users\geitb/text-fabric-data/etcbc/bhsa/tf/c\function.tf">function</a>  <a target="_blank" href="https://etcbc.github.io/bhsa/features/hebrew/c/g_word.html" title="C:\Users\geitb/text-fabric-data/etcbc/bhsa/tf/c\g_word.tf">g_word</a>  <a target="_blank" href="https://etcbc.github.io/bhsa/features/hebrew/c/g_word_utf8.html" title="C:\Users\geitb/text-fabric-data/etcbc/bhsa/tf/c\g_word_utf8.tf">g_word_utf8</a>  <a target="_blank" href="https://etcbc.github.io/bhsa/features/hebrew/c/gloss.html" title="C:\Users\geitb/text-fabric-data/etcbc/bhsa/tf/c\gloss.tf">gloss</a>  <a target="_blank" href="https://etcbc.github.io/bhsa/features/hebrew/c/gn.html" title="C:\Users\geitb/text-fabric-data/etcbc/bhsa/tf/c\gn.tf">gn</a>  <a target="_blank" href="https://etcbc.github.io/bhsa/features/hebrew/c/label.html" title="C:\Users\geitb/text-fabric-data/etcbc/bhsa/tf/c\label.tf">label</a>  <a target="_blank" href="https://etcbc.github.io/bhsa/features/hebrew/c/language.html" title="C:\Users\geitb/text-fabric-data/etcbc/bhsa/tf/c\language.tf">language</a>  <a target="_blank" href="https://etcbc.github.io/bhsa/features/hebrew/c/lex.html" title="C:\Users\geitb/text-fabric-data/etcbc/bhsa/tf/c\lex.tf">lex</a>  <a target="_blank" href="https://etcbc.github.io/bhsa/features/hebrew/c/lex_utf8.html" title="C:\Users\geitb/text-fabric-data/etcbc/bhsa/tf/c\lex_utf8.tf">lex_utf8</a>  <a target="_blank" href="https://etcbc.github.io/bhsa/features/hebrew/c/ls.html" title="C:\Users\geitb/text-fabric-data/etcbc/bhsa/tf/c\ls.tf">ls</a>  <a target="_blank" href="https://etcbc.github.io/bhsa/features/hebrew/c/nametype.html" title="C:\Users\geitb/text-fabric-data/etcbc/bhsa/tf/c\nametype.tf">nametype</a>  <a target="_blank" href="https://etcbc.github.io/bhsa/features/hebrew/c/nu.html" title="C:\Users\geitb/text-fabric-data/etcbc/bhsa/tf/c\nu.tf">nu</a>  <a target="_blank" href="https://etcbc.github.io/bhsa/features/hebrew/c/number.html" title="C:\Users\geitb/text-fabric-data/etcbc/bhsa/tf/c\number.tf">number</a>  <a target="_blank" href="https://etcbc.github.io/bhsa/features/hebrew/c/otype.html" title="C:\Users\geitb/text-fabric-data/etcbc/bhsa/tf/c\otype.tf">otype</a>  <a target="_blank" href="https://etcbc.github.io/bhsa/features/hebrew/c/pdp.html" title="C:\Users\geitb/text-fabric-data/etcbc/bhsa/tf/c\pdp.tf">pdp</a>  <a target="_blank" href="https://etcbc.github.io/bhsa/features/hebrew/c/prs_gn.html" title="C:\Users\geitb/text-fabric-data/etcbc/bhsa/tf/c\prs_gn.tf">prs_gn</a>  <a target="_blank" href="https://etcbc.github.io/bhsa/features/hebrew/c/prs_nu.html" title="C:\Users\geitb/text-fabric-data/etcbc/bhsa/tf/c\prs_nu.tf">prs_nu</a>  <a target="_blank" href="https://etcbc.github.io/bhsa/features/hebrew/c/prs_ps.html" title="C:\Users\geitb/text-fabric-data/etcbc/bhsa/tf/c\prs_ps.tf">prs_ps</a>  <a target="_blank" href="https://etcbc.github.io/bhsa/fe ...
# <style>
# @font-face {
#   font-family: "Ezra SIL";
#   src: url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/SILEOT.ttf?raw=true');
#   src: url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/SILEOT.woff?raw=true') format('woff');
# }
# .features {
#     font-family: monospace;
#     font-size: medium;
#     font-weight: bold;
#     color: #0a6611;
#     display: flex;
#     flex-flow: column nowrap;
#     padding: 0.1em;
#     margin: 0.1em;
#     direction: ltr;
# }
# .features div,.features span {
#     padding: 0;
#     margin: -0.1rem 0;
# }
# .features .f {
#     font-family: sans-serif;
#     font-size: x-small;
#     font-weight: normal;
#     color: #5555bb;
# }
# .features .xft {
#   color: #000000;
#   background-color: #eeeeee;
#   font-size: medium;
#   margin: 0.1em 0em;
# }
# .features .xft .f {
#   color: #000000;
#   background-color: #eeeeee;
#   font-style: italic;
#   font-size: small;
#   font-weight: normal;
# }
# .ltr {
#     direction: ltr ! important;
# }
# .verse {
#     display: flex;
#     flex-flow: row wrap;
#     direction: rtl;
# }
# .vl {
#     display: flex;
#     flex-flow: column nowrap;
#     justify-content: flex-end;
#     align-items: flex-end;
#     direction: ltr;
#     width: 100%;
# }
# .outeritem {
#     display: flex;
#     flex-flow: row wrap;
#     direction: rtl;
# }
# .sentence,.clause,.phrase {
#     margin-top: -1.2em;
#     margin-left: 1em;
#     background: #ffffff none repeat scroll 0 0;
#     padding: 0 0.3em;
#     border-style: solid;
#     border-radius: 0.2em;
#     font-size: small;
#     display: block;
#     width: fit-content;
#     max-width: fit-content;
#     direction: ltr;
# }
# .atoms {
#     display: flex;
#     flex-flow: row wrap;
#     margin: 0.3em;
#     padding: 0.3em;
#     direction: rtl;
#     background-color: #ffffff;
# }
# .satom,.catom,.patom {
#     margin: 0.3em;
#     padding: 0.3em;
#     border-radius: 0.3em;
#     border-style: solid;
#     display: flex;
#     flex-flow: column nowrap;
#     direction: rtl;
#     background-color: #ffffff;
# }
# .sentence {
#     border-color: #aa3333;
#     border-width: 1px;
# }
# .clause {
#     border-color: #aaaa33;
#     border-width: 1px;
# }
# .phrase {
#     border-color: #33aaaa;
#     border-width: 1px;
# }
# .satom {
#     border-color: #aa3333;
#     border-width: 4px;
# }
# .catom {
#     border-color: #aaaa33;
#     border-width: 3px;
# }
# .patom {
#     border-color: #33aaaa;
#     border-width: 3px;
# }
# .word {
#     padding: 0.1em;
#     margin: 0.1em;
#     border-radius: 0.1em;
#     border: 1px solid #cccccc;
#     display: flex;
#     flex-flow: column nowrap;
#     direction: rtl;
#     background-color: #ffffff;
# }
# .lextp {
#     padding: 0.1em;
#     margin: 0.1em;
#     border-radius: 0.1em;
#     border: 2px solid #888888;
#     width: fit-content;
#     display: flex;
#     flex-flow: column nowrap;
#     direction: rtl;
#     background-color: #ffffff;
# }
# .occs {
#     font-size: x-small;
# }
# .satom.l,.catom.l,.patom.l {
#     border-left-style: dotted
# }
# .satom.r,.catom.r,.patom.r {
#     border-right-style: dotted
# }
# .satom.lno,.catom.lno,.patom.lno {
#     border-left-style: none
# }
# .satom.rno,.catom.rno,.patom.rno {
#     border-right-style: none
# }
# .tr,.tr a:visited,.tr a:link {
#     font-family: sans-serif;
#     font-size: large;
#     color: #000044;
#     direction: ltr;
#     text-decoration: none;
# }
# .trb,.trb a:visited,.trb a:link {
#     font-family: sans-serif;
#     font-size: normal;
#     direction: ltr;
#     text-decoration: none;
# }
# .prb,.prb a:visited,.prb a:link {
#     font-family: sans-serif;
#     font-size: large;
#     direction: ltr;
#     text-decoration: none;
# }
# .h,.h a:visited,.h a:link {
#     font-family: "Ezra SIL", "SBL Hebrew", sans-serif;
#     font-size: large;
#     color: #000044;
#     direction: rtl;
#     text-decoration: none;
# }
# .hb,.hb a:visited,.hb a:link {
#     font-family: "Ezra SIL", "SBL Hebrew", sans-serif;
#     font-size: large;
#     line-height: 2;
#     direction: rtl;
#     text-decoration: none;
# }
# .vn {
#   font-size: small !important;
#   padding-right: 1em;
# }
# .rela,.function,.typ {
#     font-family: monospace;
#     font-size: small;
#     color: #0000bb;
# }
# .pdp,.pdp a:visited,.pdp a:link {
#     font-family: monospace;
#     font-size: medium;
#     color: #0000bb;
#     text-decoration: none;
# }
# .voc_lex {
#     font-family: monospace;
#     font-size: medium;
#     color: #0000bb;
# }
# .vs {
#     font-family: monospace;
#     font-size: medium;
#     font-weight: bold;
#     color: #0000bb;
# }
# .vt {
#     font-family: monospace;
#     font-size: medium;
#     font-weight: bold;
#     color: #0000bb;
# }
# .gloss {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: normal;
#     color: #444444;
# }
# .vrs {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: bold;
#     color: #444444;
# }
# .nd {
#     font-family: monospace;
#     font-size: x-small;
#     color: #999999;
# }
# .hl {
#     background-color: #ffee66;
# }
# span.hldot {
# 	background-color: var(--hl-strong);
# 	border: 0.2rem solid var(--hl-rim);
# 	border-radius: 0.4rem;
# 	/*
# 	display: inline-block;
# 	width: 0.8rem;
# 	height: 0.8rem;
# 	*/
# }
# span.hl {
# 	background-color: var(--hl-strong);
# 	border-width: 0;
# 	border-radius: 0.1rem;
# 	border-style: solid;
# }
#
# span.hlup {
# 	border-color: var(--hl-dark);
# 	border-width: 0.1rem;
# 	border-style: solid;
# 	border-radius: 0.2rem;
#   padding: 0.2rem;
# }
#
# :root {
# 	--hl-strong:        hsla( 60, 100%,  70%, 0.9  );
# 	--hl-rim:           hsla( 55, 100%,  60%, 0.9  );
# 	--hl-dark:          hsla( 55, 100%,  40%, 0.9  );
# }
# </style>
# <details open><summary><b>API members</b>:</summary>
# <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Computed/#computed-data" title="doc">C Computed</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Computed/#computed-data" title="doc">Call AllComputeds</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Computed/#computed-data" title="doc">Cs ComputedString</a><br/>
# <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Features/#edge-features" title="doc">E Edge</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Features/#edge-features" title="doc">Eall AllEdges</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Features/#edge-features" title="doc">Es EdgeString</a><br/>
# <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Fabric/#loading" title="doc">ensureLoaded</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Fabric/#loading" title="doc">TF</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Fabric/#loading" title="doc">ignored</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Fabric/#loading" title="doc">loadLog</a><br/>
# <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Locality/#locality" title="doc">L Locality</a><br/>
# <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Misc/#messaging" title="doc">cache</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Misc/#messaging" title="doc">error</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Misc/#messaging" title="doc">indent</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Misc/#messaging" title="doc">info</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Misc/#messaging" title="doc">reset</a><br/>
# <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Nodes/#navigating-nodes" title="doc">N Nodes</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Nodes/#navigating-nodes" title="doc">sortKey</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Nodes/#navigating-nodes" title="doc">sortKeyTuple</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Nodes/#navigating-nodes" title="doc">otypeRank</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Nodes/#navigating-nodes" title="doc">sortNodes</a><br/>
# <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Features/#node-features" title="doc">F Feature</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Features/#node-features" title="doc">Fall AllFeatures</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Features/#node-features" title="doc">Fs FeatureString</a><br/>
# <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Search/#search" title="doc">S Search</a><br/>
# <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Text/#text" title="doc">T Text</a></details>

# %% [markdown]
# A train and test set are defined. The model is trained on all the books of the MT, except Jonah. The model will be used to predict parts of speech for this book.

# %%
for bo in F.otype.s("book"):
    print(F.book.v(bo))
# Out:
# Genesis
# Exodus
# Leviticus
# Numeri
# Deuteronomium
# Josua
# Judices
# Samuel_I
# Samuel_II
# Reges_I
# Reges_II
# Jesaia
# Jeremia
# Ezechiel
# Hosea
# Joel
# Amos
# Obadia
# Jona
# Micha
# Nahum
# Habakuk
# Zephania
# Haggai
# Sacharia
# Maleachi
# Psalmi
# Iob
# Proverbia
# Ruth
# Canticum
# Ecclesiastes
# Threni
# Esther
# Daniel
# Esra
# Nehemia
# Chronica_I
# Chronica_II

# %% [markdown]
# The data are prepared.

# %%
def prepare_train_data():
    """"
    books is a list containing the books of the training set.
    The function returns:
    input_clauses is a list containing strings with the text of BH clauses
    output_pos is a list containing lists with all the pos of BH clauses
    input_chars is a list containing the characters occurring in the input_clauses (the input vocabulary)
    output_vocab is a list containing all the pos occurring in the bhsa
    max_len_input is the maximum length of all the input clauses in number of characters
    max_len_output is the maximum length of all the output clauses in number of phrases (+2, because a 
    start and stop sign are added)
    """

    input_clauses = []
    output_phrases = []
    input_vocab = set()
    output_vocab = set()

    for bo in F.otype.s("book"): 

        if F.book.v(bo) not in {"Genesis", "Exodus", "Leviticus", "Numeri", "Deuteronomium", "Josua", "Judices", "Samuel_I", "Samuel_II", "Reges_I", "Reges_II"}:
            continue
        
        words_in_book = L.d(bo, "word")
        
        for wo in range(words_in_book[0], words_in_book[-1] - 20):
            input_chunk = [F.sp.v(wo2) for wo2 in range(wo, wo+20)]
            
            output_prep = []
            for word in range(wo, wo+20):
                phrase = L.u(word, "phrase")[0]
                words_in_ph = L.d(phrase, "word")
                
                output_prep.append('x')
                input_vocab.add(F.sp.v(word))
                
                if word == words_in_ph[-1]:
                    output_prep.append("p")

            output_chunk = ['\t']
            for elem in output_prep:
                output_chunk.append(elem)
            output_chunk.append('\n')
    
            input_clauses.append(input_chunk)
            output_phrases.append(output_chunk)
    
    input_chars = sorted(list(input_vocab))
    
    output_vocab.add('x')
    output_vocab.add('\t')
    output_vocab.add('\n')
    output_vocab.add('p')
    output_vocab.add('c')
    output_vocab = sorted(list(output_vocab))
    
    max_len_input = max([len(clause) for clause in input_clauses])
    max_len_output = max([len(output_phr) for output_phr in output_phrases])
    
    # shuffle the data
    input_clauses, output_phrases = shuffle(input_clauses, output_phrases)
    
    return input_clauses, output_phrases, input_vocab, output_vocab, max_len_input, max_len_output

# %%
def prepare_test_data():
    """
    books is a list containing the test books
    The function returns:
    input_clauses, a list containing the text of clauses in the test books
    """
    input_clauses_test = []
    outputs_test = []
    for bo in F.otype.s("book"): 

        if F.book.v(bo) != "Jona":
            continue
        
        words_in_book = L.d(bo, "word")
        
        for wo in range(words_in_book[0], words_in_book[-1] - 20):
            input_test = [F.sp.v(wo2) for wo2 in range(wo, wo+20)]    
            input_clauses_test.append(input_test)
        
        
            output_prep = []
            for word in range(wo, wo+20):
                phrase = L.u(word, "phrase")[0]
                words_in_ph = L.d(phrase, "word")
                
                output_prep.append('x')
                
                if word == words_in_ph[-1]:
                    output_prep.append("p")
                    
            outputs_test.append(output_prep)
    
    return input_clauses_test, outputs_test

# %%
def create_dicts(input_vocab, output_vocab):
    """
    The network can only handle numeric data. This function provides four dicts. 
    Two of them map between integers and the input characters (one dict for every direction), the other two 
    map between integers and parts of speech.
    """

    
    input_idx2char = {}
    input_char2idx = {}

    for k, v in enumerate(input_chars):
        input_idx2char[k] = v
        input_char2idx[v] = k
        
    output_idx2char = {}
    output_char2idx = {}
    
    for k, v in enumerate(output_vocab):
        output_idx2char[k] = v
        output_char2idx[v] = k
     
    
    return input_idx2char, input_char2idx, output_idx2char, output_char2idx

# %%
def one_hot_encode(nb_samples, max_len_input, max_len_output, input_chars, output_vocab, input_char2idx, output_char2idx, input_clauses, output_pos):
    """
    Categorical data are generally one-hot encoded in neural networks, which is done here.
    
    """

    tokenized_input_data = np.zeros(shape = (nb_samples,max_len_input,len(input_chars)), dtype='float32')
    tokenized_output = np.zeros(shape = (nb_samples,max_len_output,len(output_vocab)), dtype='float32')
    target_data = np.zeros((nb_samples, max_len_output, len(output_vocab)),dtype='float32')

    for i in range(nb_samples):
        for k, ch in enumerate(input_clauses[i]):
            tokenized_input_data[i, k, input_char2idx[ch]] = 1
        
        for k, ch in enumerate(output_pos[i]):
            tokenized_output[i, k, output_char2idx[ch]] = 1

            # decoder_target_data will be ahead by one timestep and will not include the start character.
            if k > 0:
                target_data[i, k-1, output_char2idx[ch]] = 1
                
    return tokenized_input_data, tokenized_output, target_data

# %%
def define_LSTM_model(input_chars, output_vocab):
    """
    
    
    """

    # Encoder model

    encoder_input = Input(shape=(None,len(input_chars)))
    encoder_LSTM = LSTM(512,activation = 'relu',return_state = True, return_sequences=True)(encoder_input)
    encoder_LSTM = LSTM(512,return_state = True)(encoder_LSTM)
    encoder_outputs, encoder_h, encoder_c = encoder_LSTM
    encoder_states = [encoder_h, encoder_c]
    
    # Decoder model

    decoder_input = Input(shape=(None,len(output_vocab)))
    decoder_LSTM = LSTM(512, return_sequences=True, return_state = True)
    decoder_out, _ , _ = decoder_LSTM(decoder_input, initial_state=encoder_states)
    decoder_dense = Dense(len(output_vocab), activation='softmax')
    decoder_out = decoder_dense (decoder_out)
    
    model = Model(inputs=[encoder_input, decoder_input],outputs=[decoder_out])

    model.summary()

    return encoder_input, encoder_states, decoder_input, decoder_LSTM, decoder_dense, model

# %%
def compile_and_train(model, tokenized_input, tokenized_output, batch_size, epochs, validation_split):

    model.compile(optimizer='adam', loss='categorical_crossentropy')
    model.fit(x=[tokenized_input,tokenized_output], 
              y=target_data,
              batch_size=batch_size,
              epochs=epochs,
              validation_split=validation_split)
    
    return model

# %%
nb_samples = 200000

input_clauses, output_pos, input_chars, output_vocab, max_len_input, max_len_output = prepare_train_data()
input_idx2char, input_char2idx, output_idx2char, output_char2idx = create_dicts(input_chars, output_vocab)
tokenized_input, tokenized_output, target_data = one_hot_encode(nb_samples, max_len_input, max_len_output, input_chars, output_vocab, input_char2idx, output_char2idx, input_clauses, output_pos)

# %%
test_clauses, output_test = prepare_test_data()
tokenized_test_data, _, _ = one_hot_encode(len(test_clauses), max_len_input, max_len_output, input_chars, output_vocab, input_char2idx, output_char2idx, test_clauses, output_pos)

# %%
len(input_clauses)
# Out:
# 211838

# %%
encoder_input, encoder_states, decoder_input, decoder_LSTM, decoder_dense, model = define_LSTM_model(input_chars, output_vocab)
model = compile_and_train(model, tokenized_input, tokenized_output, 512, 11, 0.1)
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_25 (InputLayer)           (None, None, 14)     0
# __________________________________________________________________________________________________
# lstm_19 (LSTM)                  [(None, None, 512),  1079296     input_25[0][0]
# __________________________________________________________________________________________________
# input_26 (InputLayer)           (None, None, 5)      0
# __________________________________________________________________________________________________
# lstm_20 (LSTM)                  [(None, 512), (None, 2099200     lstm_19[0][0]
#                                                                  lstm_19[0][1]
#                                                                  lstm_19[0][2]
# __________________________________________________________________________________________________
# lstm_21 (LSTM)                  [(None, None, 512),  1060864     input_26[0][0]
#                                                                  lstm_20[0][1]
#                                                                  lstm_20[0][2]
# __________________________________________________________________________________________________
# dense_7 (Dense)                 (None, None, 5)      2565        lstm_21[0][0]
# ==================================================================================================
# Total params: 4,241,925
# Trainable params: 4,241,925
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Train on 180000 samples, validate on 20000 samples
# Epoch 1/11
# 180000/180000 [==============================] - 86s 477us/step - loss: 0.3941 - val_loss: 0.3097
# Epoch 2/11
# 180000/180000 [==============================] - 82s 457us/step - loss: 0.2811 - val_loss: 0.2337
# Epoch 3/11
# 180000/180000 [==============================] - 83s 461us/step - loss: 0.2080 - val_loss: 0.3717
# Epoch 4/11
# 180000/180000 [==============================] - 83s 462us/step - loss: 0.1723 - val_loss: 0.1354
# Epoch 5/11
# 180000/180000 [==============================] - 83s 463us/step - loss: 0.1942 - val_loss: 0.1536
# Epoch 6/11
# 180000/180000 [==============================] - 83s 462us/step - loss: 0.1277 - val_loss: 0.1093
# Epoch 7/11
# 180000/180000 [==============================] - 83s 462us/step - loss: 0.1013 - val_loss: 0.1008
# Epoch 8/11
# 180000/180000 [==============================] - 83s 462us/step - loss: 0.1018 - val_loss: 0.0905
# Epoch 9/11
# 180000/180000 [==============================] - 83s 462us/step - loss: 0.0823 - val_loss: 0.0811
# Epoch 10/11
# 180000/180000 [==============================] - 83s 462us/step - loss: 0.0734 - val_loss: 0.0721
# Epoch 11/11
# 180000/180000 [==============================] - 83s 463us/step - loss: 0.0660 - val_loss: 0.0670

# %%
# Inference models for testing

# Encoder inference model
encoder_model_inf = Model(encoder_input, encoder_states)

# Decoder inference model
decoder_state_input_h = Input(shape=(512,))
decoder_state_input_c = Input(shape=(512,))
decoder_input_states = [decoder_state_input_h, decoder_state_input_c]

decoder_out, decoder_h, decoder_c = decoder_LSTM(decoder_input, 
                                                 initial_state=decoder_input_states)

decoder_states = [decoder_h , decoder_c]

decoder_out = decoder_dense(decoder_out)

decoder_model_inf = Model(inputs=[decoder_input] + decoder_input_states,
                          outputs=[decoder_out] + decoder_states )

# %%
def decode_seq(inp_seq):
    
    # Initial states value is coming from the encoder 
    states_val = encoder_model_inf.predict(inp_seq)
    
    target_seq = np.zeros((1, 1, len(output_vocab)))
    target_seq[0, 0, output_char2idx['\t']] = 1
    
    pred_pos = []
    stop_condition = False
    
    while not stop_condition:
        
        decoder_out, decoder_h, decoder_c = decoder_model_inf.predict(x=[target_seq] + states_val)
        max_val_index = np.argmax(decoder_out[0,-1,:])
        sampled_out_char = output_idx2char[max_val_index]
        pred_pos.append(sampled_out_char)
        
        if (sampled_out_char == '\n'):
            stop_condition = True
        
        target_seq = np.zeros((1, 1, len(output_vocab)))
        target_seq[0, 0, max_val_index] = 1
        
        states_val = [decoder_h, decoder_c]
        
    return pred_pos

# %%
for seq_index in range(200):
    inp_seq = tokenized_test_data[seq_index:seq_index+1]
    
    pred_pos = decode_seq(inp_seq)
    print('-')
    print('Input clause:', test_clauses[seq_index])
    print('Predicted phrase boundaries:', pred_pos[:-1])
    print('True phrase boundaries', output_test[seq_index])
# Out:
# -
# Input clause: ['conj', 'verb', 'subs', 'nmpr', 'prep', 'nmpr', 'subs', 'nmpr', 'prep', 'verb', 'verb', 'verb', 'prep', 'nmpr', 'art', 'subs', 'art', 'adjv', 'conj', 'verb']
# Predicted phrase boundaries: ['x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'x', 'x', 'x', 'p', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'x', 'x', 'x', 'p', 'x', 'p', 'x', 'p']
# True phrase boundaries ['x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'x', 'x', 'x', 'p', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'x', 'x', 'x', 'x', 'p', 'x', 'p', 'x', 'p']
# -
# Input clause: ['verb', 'subs', 'nmpr', 'prep', 'nmpr', 'subs', 'nmpr', 'prep', 'verb', 'verb', 'verb', 'prep', 'nmpr', 'art', 'subs', 'art', 'adjv', 'conj', 'verb', 'prep']
# Predicted phrase boundaries: ['x', 'p', 'x', 'x', 'p', 'x', 'x', 'x', 'x', 'p', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'x', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x']
# True phrase boundaries ['x', 'p', 'x', 'x', 'p', 'x', 'x', 'x', 'x', 'p', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'x', 'x', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p']
# -
# Input clause: ['subs', 'nmpr', 'prep', 'nmpr', 'subs', 'nmpr', 'prep', 'verb', 'verb', 'verb', 'prep', 'nmpr', 'art', 'subs', 'art', 'adjv', 'conj', 'verb', 'prep', 'conj']
# Predicted phrase boundaries: ['x', 'x', 'p', 'x', 'x', 'x', 'x', 'p', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'x', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p']
# True phrase boundaries ['x', 'x', 'p', 'x', 'x', 'x', 'x', 'p', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'x', 'x', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p']
# -
# Input clause: ['nmpr', 'prep', 'nmpr', 'subs', 'nmpr', 'prep', 'verb', 'verb', 'verb', 'prep', 'nmpr', 'art', 'subs', 'art', 'adjv', 'conj', 'verb', 'prep', 'conj', 'verb']
# Predicted phrase boundaries: ['x', 'p', 'x', 'x', 'x', 'x', 'p', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'x', 'x', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p']
# True phrase boundaries ['x', 'p', 'x', 'x', 'x', 'x', 'p', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'x', 'x', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p']
# -
# Input clause: ['prep', 'nmpr', 'subs', 'nmpr', 'prep', 'verb', 'verb', 'verb', 'prep', 'nmpr', 'art', 'subs', 'art', 'adjv', 'conj', 'verb', 'prep', 'conj', 'verb', 'subs']
# Predicted phrase boundaries: ['x', 'x', 'x', 'x', 'p', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'x', 'x', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x']
# True phrase boundaries ['x', 'x', 'x', 'x', 'p', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'x', 'x', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p']
# -
# Input clause: ['nmpr', 'subs', 'nmpr', 'prep', 'verb', 'verb', 'verb', 'prep', 'nmpr', 'art', 'subs', 'art', 'adjv', 'conj', 'verb', 'prep', 'conj', 'verb', 'subs', 'prep']
# Predicted phrase boundaries: ['x', 'x', 'x', 'p', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'x', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x']
# True phrase boundaries ['x', 'x', 'x', 'p', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'x', 'x', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x']
# -
# Input clause: ['subs', 'nmpr', 'prep', 'verb', 'verb', 'verb', 'prep', 'nmpr', 'art', 'subs', 'art', 'adjv', 'conj', 'verb', 'prep', 'conj', 'verb', 'subs', 'prep', 'subs']
# Predicted phrase boundaries: ['x', 'x', 'p', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'x', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'p']
# True phrase boundaries ['x', 'x', 'p', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'x', 'x', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'p']
# -
# Input clause: ['nmpr', 'prep', 'verb', 'verb', 'verb', 'prep', 'nmpr', 'art', 'subs', 'art', 'adjv', 'conj', 'verb', 'prep', 'conj', 'verb', 'subs', 'prep', 'subs', 'conj']
# Predicted phrase boundaries: ['x', 'p', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'x', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'p']
# True phrase boundaries ['x', 'p', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'x', 'x', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'p']
# -
# Input clause: ['prep', 'verb', 'verb', 'verb', 'prep', 'nmpr', 'art', 'subs', 'art', 'adjv', 'conj', 'verb', 'prep', 'conj', 'verb', 'subs', 'prep', 'subs', 'conj', 'verb']
# Predicted phrase boundaries: ['x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'x', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'p', 'x', 'p']
# True phrase boundaries ['x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'x', 'x', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'p', 'x', 'p']
# -
# Input clause: ['verb', 'verb', 'verb', 'prep', 'nmpr', 'art', 'subs', 'art', 'adjv', 'conj', 'verb', 'prep', 'conj', 'verb', 'subs', 'prep', 'subs', 'conj', 'verb', 'nmpr']
# Predicted phrase boundaries: ['x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'x', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p']
# True phrase boundaries ['x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'x', 'x', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p']
# -
# Input clause: ['verb', 'verb', 'prep', 'nmpr', 'art', 'subs', 'art', 'adjv', 'conj', 'verb', 'prep', 'conj', 'verb', 'subs', 'prep', 'subs', 'conj', 'verb', 'nmpr', 'prep']
# Predicted phrase boundaries: ['x', 'p', 'x', 'p', 'x', 'x', 'x', 'x', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x']
# True phrase boundaries ['x', 'p', 'x', 'p', 'x', 'x', 'x', 'x', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x']
# -
# Input clause: ['verb', 'prep', 'nmpr', 'art', 'subs', 'art', 'adjv', 'conj', 'verb', 'prep', 'conj', 'verb', 'subs', 'prep', 'subs', 'conj', 'verb', 'nmpr', 'prep', 'verb']
# Predicted phrase boundaries: ['x', 'p', 'x', 'x', 'x', 'x', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'p']
# True phrase boundaries ['x', 'p', 'x', 'x', 'x', 'x', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'p']
# -
# Input clause: ['prep', 'nmpr', 'art', 'subs', 'art', 'adjv', 'conj', 'verb', 'prep', 'conj', 'verb', 'subs', 'prep', 'subs', 'conj', 'verb', 'nmpr', 'prep', 'verb', 'nmpr']
# Predicted phrase boundaries: ['x', 'x', 'x', 'x', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'p']
# True phrase boundaries ['x', 'x', 'x', 'x', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'p']
# -
# Input clause: ['nmpr', 'art', 'subs', 'art', 'adjv', 'conj', 'verb', 'prep', 'conj', 'verb', 'subs', 'prep', 'subs', 'conj', 'verb', 'nmpr', 'prep', 'verb', 'nmpr', 'prep']
# Predicted phrase boundaries: ['x', 'x', 'x', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'p', 'x']
# True phrase boundaries ['x', 'x', 'x', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'p', 'x']
# -
# Input clause: ['art', 'subs', 'art', 'adjv', 'conj', 'verb', 'prep', 'conj', 'verb', 'subs', 'prep', 'subs', 'conj', 'verb', 'nmpr', 'prep', 'verb', 'nmpr', 'prep', 'prep']
# Predicted phrase boundaries: ['x', 'x', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x']
# True phrase boundaries ['x', 'x', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'p', 'x', 'x']
# -
# Input clause: ['subs', 'art', 'adjv', 'conj', 'verb', 'prep', 'conj', 'verb', 'subs', 'prep', 'subs', 'conj', 'verb', 'nmpr', 'prep', 'verb', 'nmpr', 'prep', 'prep', 'subs']
# Predicted phrase boundaries: ['x', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x']
# True phrase boundaries ['x', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'p', 'x', 'x', 'x']
# -
# Input clause: ['art', 'adjv', 'conj', 'verb', 'prep', 'conj', 'verb', 'subs', 'prep', 'subs', 'conj', 'verb', 'nmpr', 'prep', 'verb', 'nmpr', 'prep', 'prep', 'subs', 'nmpr']
# Predicted phrase boundaries: ['x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'x', 'p']
# True phrase boundaries ['x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'p', 'x', 'x', 'x', 'x', 'p']
# -
# Input clause: ['adjv', 'conj', 'verb', 'prep', 'conj', 'verb', 'subs', 'prep', 'subs', 'conj', 'verb', 'nmpr', 'prep', 'verb', 'nmpr', 'prep', 'prep', 'subs', 'nmpr', 'conj']
# Predicted phrase boundaries: ['x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'x', 'p', 'x', 'p']
# True phrase boundaries ['x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'p', 'x', 'x', 'x', 'x', 'p', 'x', 'p']
# -
# Input clause: ['conj', 'verb', 'prep', 'conj', 'verb', 'subs', 'prep', 'subs', 'conj', 'verb', 'nmpr', 'prep', 'verb', 'nmpr', 'prep', 'prep', 'subs', 'nmpr', 'conj', 'verb']
# Predicted phrase boundaries: ['x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'x', 'p', 'x', 'p', 'x', 'p']
# True phrase boundaries ['x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'p', 'x', 'x', 'x', 'x', 'p', 'x', 'p', 'x', 'p']
# -
# Input clause: ['verb', 'prep', 'conj', 'verb', 'subs', 'prep', 'subs', 'conj', 'verb', 'nmpr', 'prep', 'verb', 'nmpr', 'prep', 'prep', 'subs', 'nmpr', 'conj', 'verb', 'nmpr']
# Predicted phrase boundaries: ['x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p']
# True phrase boundaries ['x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'p', 'x', 'x', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p']
# -
# Input clause: ['prep', 'conj', 'verb', 'subs', 'prep', 'subs', 'conj', 'verb', 'nmpr', 'prep', 'verb', 'nmpr', 'prep', 'prep', 'subs', 'nmpr', 'conj', 'verb', 'nmpr', 'conj']
# Predicted phrase boundaries: ['x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'p', 'x', 'x', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p']
# True phrase boundaries ['x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'p', 'x', 'x', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p']
# -
# Input clause: ['conj', 'verb', 'subs', 'prep', 'subs', 'conj', 'verb', 'nmpr', 'prep', 'verb', 'nmpr', 'prep', 'prep', 'subs', 'nmpr', 'conj', 'verb', 'nmpr', 'conj', 'verb']
# Predicted phrase boundaries: ['x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'p', 'x', 'x', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p']
# True phrase boundaries ['x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'p', 'x', 'x', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p']
# -
# Input clause: ['verb', 'subs', 'prep', 'subs', 'conj', 'verb', 'nmpr', 'prep', 'verb', 'nmpr', 'prep', 'prep', 'subs', 'nmpr', 'conj', 'verb', 'nmpr', 'conj', 'verb', 'subs']
# Predicted phrase boundaries: ['x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'p', 'x', 'x', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p']
# True phrase boundaries ['x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'p', 'x', 'x', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p']
# -
# Input clause: ['subs', 'prep', 'subs', 'conj', 'verb', 'nmpr', 'prep', 'verb', 'nmpr', 'prep', 'prep', 'subs', 'nmpr', 'conj', 'verb', 'nmpr', 'conj', 'verb', 'subs', 'verb']
# Predicted phrase boundaries: ['x', 'p', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p']
# True phrase boundaries ['x', 'p', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'p', 'x', 'x', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p']
# -
# Input clause: ['prep', 'subs', 'conj', 'verb', 'nmpr', 'prep', 'verb', 'nmpr', 'prep', 'prep', 'subs', 'nmpr', 'conj', 'verb', 'nmpr', 'conj', 'verb', 'subs', 'verb', 'nmpr']
# Predicted phrase boundaries: ['x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'x', 'p', 'x', 'p', 'x', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p']
# True phrase boundaries ['x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'p', 'x', 'x', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p']
# -
# Input clause: ['subs', 'conj', 'verb', 'nmpr', 'prep', 'verb', 'nmpr', 'prep', 'prep', 'subs', 'nmpr', 'conj', 'verb', 'nmpr', 'conj', 'verb', 'subs', 'verb', 'nmpr', 'conj']
# Predicted phrase boundaries: ['x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'p', 'x', 'x', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'x', 'x']
# True phrase boundaries ['x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'p', 'x', 'x', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p']
# -
# Input clause: ['conj', 'verb', 'nmpr', 'prep', 'verb', 'nmpr', 'prep', 'prep', 'subs', 'nmpr', 'conj', 'verb', 'nmpr', 'conj', 'verb', 'subs', 'verb', 'nmpr', 'conj', 'verb']
# Predicted phrase boundaries: ['x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'p', 'x', 'x', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p']
# True phrase boundaries ['x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'p', 'x', 'x', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p']
# -
# Input clause: ['verb', 'nmpr', 'prep', 'verb', 'nmpr', 'prep', 'prep', 'subs', 'nmpr', 'conj', 'verb', 'nmpr', 'conj', 'verb', 'subs', 'verb', 'nmpr', 'conj', 'verb', 'subs']
# Predicted phrase boundaries: ['x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p']
# True phrase boundaries ['x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'p', 'x', 'x', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p']
# -
# Input clause: ['nmpr', 'prep', 'verb', 'nmpr', 'prep', 'prep', 'subs', 'nmpr', 'conj', 'verb', 'nmpr', 'conj', 'verb', 'subs', 'verb', 'nmpr', 'conj', 'verb', 'subs', 'conj']
# Predicted phrase boundaries: ['x', 'p', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p']
# True phrase boundaries ['x', 'p', 'x', 'x', 'p', 'x', 'p', 'x', 'x', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p']
# -
# Input clause: ['prep', 'verb', 'nmpr', 'prep', 'prep', 'subs', 'nmpr', 'conj', 'verb', 'nmpr', 'conj', 'verb', 'subs', 'verb', 'nmpr', 'conj', 'verb', 'subs', 'conj', 'verb']
# Predicted phrase boundaries: ['x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p']
# True phrase boundaries ['x', 'x', 'p', 'x', 'p', 'x', 'x', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p']
# -
# Input clause: ['verb', 'nmpr', 'prep', 'prep', 'subs', 'nmpr', 'conj', 'verb', 'nmpr', 'conj', 'verb', 'subs', 'verb', 'nmpr', 'conj', 'verb', 'subs', 'conj', 'verb', 'prep']
# Predicted phrase boundaries: ['x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x']
# True phrase boundaries ['x', 'p', 'x', 'p', 'x', 'x', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p']
# -
# Input clause: ['nmpr', 'prep', 'prep', 'subs', 'nmpr', 'conj', 'verb', 'nmpr', 'conj', 'verb', 'subs', 'verb', 'nmpr', 'conj', 'verb', 'subs', 'conj', 'verb', 'prep', 'prep']
# Predicted phrase boundaries: ['x', 'p', 'x', 'x', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x']
# True phrase boundaries ['x', 'p', 'x', 'x', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x']
# -
# Input clause: ['prep', 'prep', 'subs', 'nmpr', 'conj', 'verb', 'nmpr', 'conj', 'verb', 'subs', 'verb', 'nmpr', 'conj', 'verb', 'subs', 'conj', 'verb', 'prep', 'prep', 'verb']
# Predicted phrase boundaries: ['x', 'p', 'x', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'p']
# True phrase boundaries ['x', 'x', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'p']
# -
# Input clause: ['prep', 'subs', 'nmpr', 'conj', 'verb', 'nmpr', 'conj', 'verb', 'subs', 'verb', 'nmpr', 'conj', 'verb', 'subs', 'conj', 'verb', 'prep', 'prep', 'verb', 'prep']
# Predicted phrase boundaries: ['x', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x']
# True phrase boundaries ['x', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'p']
# -
# Input clause: ['subs', 'nmpr', 'conj', 'verb', 'nmpr', 'conj', 'verb', 'subs', 'verb', 'nmpr', 'conj', 'verb', 'subs', 'conj', 'verb', 'prep', 'prep', 'verb', 'prep', 'nmpr']
# Predicted phrase boundaries: ['x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'x', 'p']
# True phrase boundaries ['x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'p', 'x', 'p']
# -
# Input clause: ['nmpr', 'conj', 'verb', 'nmpr', 'conj', 'verb', 'subs', 'verb', 'nmpr', 'conj', 'verb', 'subs', 'conj', 'verb', 'prep', 'prep', 'verb', 'prep', 'nmpr', 'prep']
# Predicted phrase boundaries: ['x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'x', 'p', 'x']
# True phrase boundaries ['x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x']
# -
# Input clause: ['conj', 'verb', 'nmpr', 'conj', 'verb', 'subs', 'verb', 'nmpr', 'conj', 'verb', 'subs', 'conj', 'verb', 'prep', 'prep', 'verb', 'prep', 'nmpr', 'prep', 'prep']
# Predicted phrase boundaries: ['x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'x', 'p', 'x', 'x']
# True phrase boundaries ['x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x']
# -
# Input clause: ['verb', 'nmpr', 'conj', 'verb', 'subs', 'verb', 'nmpr', 'conj', 'verb', 'subs', 'conj', 'verb', 'prep', 'prep', 'verb', 'prep', 'nmpr', 'prep', 'prep', 'subs']
# Predicted phrase boundaries: ['x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'x', 'p', 'x', 'x', 'x']
# True phrase boundaries ['x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'x']
# -
# Input clause: ['nmpr', 'conj', 'verb', 'subs', 'verb', 'nmpr', 'conj', 'verb', 'subs', 'conj', 'verb', 'prep', 'prep', 'verb', 'prep', 'nmpr', 'prep', 'prep', 'subs', 'nmpr']
# Predicted phrase boundaries: ['x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'x', 'p', 'x', 'x', 'p', 'x', 'x', 'x', 'p']
# True phrase boundaries ['x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'x', 'x', 'p']
# -
# Input clause: ['conj', 'verb', 'subs', 'verb', 'nmpr', 'conj', 'verb', 'subs', 'conj', 'verb', 'prep', 'prep', 'verb', 'prep', 'nmpr', 'prep', 'prep', 'subs', 'nmpr', 'conj']
# Predicted phrase boundaries: ['x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'x', 'p', 'x', 'x', 'p', 'x', 'x', 'x', 'p', 'x', 'p']
# True phrase boundaries ['x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'x', 'x', 'p', 'x', 'p']
# -
# Input clause: ['verb', 'subs', 'verb', 'nmpr', 'conj', 'verb', 'subs', 'conj', 'verb', 'prep', 'prep', 'verb', 'prep', 'nmpr', 'prep', 'prep', 'subs', 'nmpr', 'conj', 'nmpr']
# Predicted phrase boundaries: ['x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'x', 'p', 'x', 'x', 'p', 'x', 'x', 'x', 'p', 'x', 'p', 'x', 'p']
# True phrase boundaries ['x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'x', 'x', 'p', 'x', 'p', 'x', 'p']
# -
# Input clause: ['subs', 'verb', 'nmpr', 'conj', 'verb', 'subs', 'conj', 'verb', 'prep', 'prep', 'verb', 'prep', 'nmpr', 'prep', 'prep', 'subs', 'nmpr', 'conj', 'nmpr', 'verb']
# Predicted phrase boundaries: ['x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'x', 'p', 'x', 'x', 'p', 'x', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p']
# True phrase boundaries ['x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p']
# -
# Input clause: ['verb', 'nmpr', 'conj', 'verb', 'subs', 'conj', 'verb', 'prep', 'prep', 'verb', 'prep', 'nmpr', 'prep', 'prep', 'subs', 'nmpr', 'conj', 'nmpr', 'verb', 'subs']
# Predicted phrase boundaries: ['x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'x', 'p', 'x', 'x', 'p', 'x', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x']
# True phrase boundaries ['x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x']
# -
# Input clause: ['nmpr', 'conj', 'verb', 'subs', 'conj', 'verb', 'prep', 'prep', 'verb', 'prep', 'nmpr', 'prep', 'prep', 'subs', 'nmpr', 'conj', 'nmpr', 'verb', 'subs', 'adjv']
# Predicted phrase boundaries: ['x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'x', 'p', 'x', 'x', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'p']
# True phrase boundaries ['x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'p']
# -
# Input clause: ['conj', 'verb', 'subs', 'conj', 'verb', 'prep', 'prep', 'verb', 'prep', 'nmpr', 'prep', 'prep', 'subs', 'nmpr', 'conj', 'nmpr', 'verb', 'subs', 'adjv', 'prep']
# Predicted phrase boundaries: ['x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'x', 'p', 'x', 'x', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x']
# True phrase boundaries ['x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x']
# -
# Input clause: ['verb', 'subs', 'conj', 'verb', 'prep', 'prep', 'verb', 'prep', 'nmpr', 'prep', 'prep', 'subs', 'nmpr', 'conj', 'nmpr', 'verb', 'subs', 'adjv', 'prep', 'art']
# Predicted phrase boundaries: ['x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'x', 'p', 'x', 'x', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'x']
# True phrase boundaries ['x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'x']
# -
# Input clause: ['subs', 'conj', 'verb', 'prep', 'prep', 'verb', 'prep', 'nmpr', 'prep', 'prep', 'subs', 'nmpr', 'conj', 'nmpr', 'verb', 'subs', 'adjv', 'prep', 'art', 'subs']
# Predicted phrase boundaries: ['x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'x', 'p', 'x', 'p', 'x', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'x', 'x', 'p']
# True phrase boundaries ['x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'x', 'x', 'p']
# -
# Input clause: ['conj', 'verb', 'prep', 'prep', 'verb', 'prep', 'nmpr', 'prep', 'prep', 'subs', 'nmpr', 'conj', 'nmpr', 'verb', 'subs', 'adjv', 'prep', 'art', 'subs', 'conj']
# Predicted phrase boundaries: ['x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'x', 'p', 'x', 'p', 'x', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'x', 'x', 'p', 'x', 'p']
# True phrase boundaries ['x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'x', 'x', 'p', 'x', 'p']
# -
# Input clause: ['verb', 'prep', 'prep', 'verb', 'prep', 'nmpr', 'prep', 'prep', 'subs', 'nmpr', 'conj', 'nmpr', 'verb', 'subs', 'adjv', 'prep', 'art', 'subs', 'conj', 'verb']
# Predicted phrase boundaries: ['x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'x', 'p', 'x', 'x', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'x', 'x', 'p', 'x', 'p', 'x', 'p']
# True phrase boundaries ['x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'x', 'x', 'p', 'x', 'p', 'x', 'p']
# -
# Input clause: ['prep', 'prep', 'verb', 'prep', 'nmpr', 'prep', 'prep', 'subs', 'nmpr', 'conj', 'nmpr', 'verb', 'subs', 'adjv', 'prep', 'art', 'subs', 'conj', 'verb', 'subs']
# Predicted phrase boundaries: ['x', 'p', 'x', 'x', 'p', 'x', 'x', 'p', 'x', 'x', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p']
# True phrase boundaries ['x', 'p', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x']
# -
# Input clause: ['prep', 'verb', 'prep', 'nmpr', 'prep', 'prep', 'subs', 'nmpr', 'conj', 'nmpr', 'verb', 'subs', 'adjv', 'prep', 'art', 'subs', 'conj', 'verb', 'subs', 'adjv']
# Predicted phrase boundaries: ['x', 'x', 'p', 'x', 'x', 'p', 'x', 'x', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'p']
# True phrase boundaries ['x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'p']
# -
# Input clause: ['verb', 'prep', 'nmpr', 'prep', 'prep', 'subs', 'nmpr', 'conj', 'nmpr', 'verb', 'subs', 'adjv', 'prep', 'art', 'subs', 'conj', 'verb', 'subs', 'adjv', 'prep']
# Predicted phrase boundaries: ['x', 'p', 'x', 'x', 'p', 'x', 'x', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x']
# True phrase boundaries ['x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x']
# -
# Input clause: ['prep', 'nmpr', 'prep', 'prep', 'subs', 'nmpr', 'conj', 'nmpr', 'verb', 'subs', 'adjv', 'prep', 'art', 'subs', 'conj', 'verb', 'subs', 'adjv', 'prep', 'art']
# Predicted phrase boundaries: ['x', 'x', 'p', 'x', 'p', 'x', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'x']
# True phrase boundaries ['x', 'p', 'x', 'p', 'x', 'x', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'x']
# -
# Input clause: ['nmpr', 'prep', 'prep', 'subs', 'nmpr', 'conj', 'nmpr', 'verb', 'subs', 'adjv', 'prep', 'art', 'subs', 'conj', 'verb', 'subs', 'adjv', 'prep', 'art', 'subs']
# Predicted phrase boundaries: ['x', 'p', 'x', 'p', 'x', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'x', 'x', 'p']
# True phrase boundaries ['x', 'p', 'x', 'x', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'x', 'x', 'p']
# -
# Input clause: ['prep', 'prep', 'subs', 'nmpr', 'conj', 'nmpr', 'verb', 'subs', 'adjv', 'prep', 'art', 'subs', 'conj', 'verb', 'subs', 'adjv', 'prep', 'art', 'subs', 'conj']
# Predicted phrase boundaries: ['x', 'p', 'x', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'x', 'x', 'p', 'x', 'p']
# True phrase boundaries ['x', 'x', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'x', 'x', 'p', 'x', 'p']
# -
# Input clause: ['prep', 'subs', 'nmpr', 'conj', 'nmpr', 'verb', 'subs', 'adjv', 'prep', 'art', 'subs', 'conj', 'verb', 'subs', 'adjv', 'prep', 'art', 'subs', 'conj', 'art']
# Predicted phrase boundaries: ['x', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'x', 'x', 'p', 'x', 'p', 'x']
# True phrase boundaries ['x', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'x', 'x', 'p', 'x', 'p', 'x']
# -
# Input clause: ['subs', 'nmpr', 'conj', 'nmpr', 'verb', 'subs', 'adjv', 'prep', 'art', 'subs', 'conj', 'verb', 'subs', 'adjv', 'prep', 'art', 'subs', 'conj', 'art', 'subs']
# Predicted phrase boundaries: ['x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'x', 'x', 'p', 'x', 'p', 'x', 'x', 'p']
# True phrase boundaries ['x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'x', 'x', 'p', 'x', 'p', 'x', 'x', 'p']
# -
# Input clause: ['nmpr', 'conj', 'nmpr', 'verb', 'subs', 'adjv', 'prep', 'art', 'subs', 'conj', 'verb', 'subs', 'adjv', 'prep', 'art', 'subs', 'conj', 'art', 'subs', 'verb']
# Predicted phrase boundaries: ['x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'x', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'p']
# True phrase boundaries ['x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'x', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'p']
# -
# Input clause: ['conj', 'nmpr', 'verb', 'subs', 'adjv', 'prep', 'art', 'subs', 'conj', 'verb', 'subs', 'adjv', 'prep', 'art', 'subs', 'conj', 'art', 'subs', 'verb', 'prep']
# Predicted phrase boundaries: ['x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'x', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'p', 'x']
# True phrase boundaries ['x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'x', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'p', 'x']
# -
# Input clause: ['nmpr', 'verb', 'subs', 'adjv', 'prep', 'art', 'subs', 'conj', 'verb', 'subs', 'adjv', 'prep', 'art', 'subs', 'conj', 'art', 'subs', 'verb', 'prep', 'verb']
# Predicted phrase boundaries: ['x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'x', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'p', 'x', 'x', 'p']
# True phrase boundaries ['x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'x', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'p', 'x', 'x', 'p']
# -
# Input clause: ['verb', 'subs', 'adjv', 'prep', 'art', 'subs', 'conj', 'verb', 'subs', 'adjv', 'prep', 'art', 'subs', 'conj', 'art', 'subs', 'verb', 'prep', 'verb', 'conj']
# Predicted phrase boundaries: ['x', 'p', 'x', 'x', 'p', 'x', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'p']
# True phrase boundaries ['x', 'p', 'x', 'x', 'p', 'x', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'x', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'p']
# -
# Input clause: ['subs', 'adjv', 'prep', 'art', 'subs', 'conj', 'verb', 'subs', 'adjv', 'prep', 'art', 'subs', 'conj', 'art', 'subs', 'verb', 'prep', 'verb', 'conj', 'verb']
# Predicted phrase boundaries: ['x', 'x', 'p', 'x', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'x', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'p', 'x', 'p']
# True phrase boundaries ['x', 'x', 'p', 'x', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'x', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'p', 'x', 'p']
# -
# Input clause: ['adjv', 'prep', 'art', 'subs', 'conj', 'verb', 'subs', 'adjv', 'prep', 'art', 'subs', 'conj', 'art', 'subs', 'verb', 'prep', 'verb', 'conj', 'verb', 'art']
# Predicted phrase boundaries: ['x', 'p', 'x', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'x', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x']
# True phrase boundaries ['x', 'p', 'x', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'x', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x']
# -
# Input clause: ['prep', 'art', 'subs', 'conj', 'verb', 'subs', 'adjv', 'prep', 'art', 'subs', 'conj', 'art', 'subs', 'verb', 'prep', 'verb', 'conj', 'verb', 'art', 'subs']
# Predicted phrase boundaries: ['x', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'x', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'p']
# True phrase boundaries ['x', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'x', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'p']
# -
# Input clause: ['art', 'subs', 'conj', 'verb', 'subs', 'adjv', 'prep', 'art', 'subs', 'conj', 'art', 'subs', 'verb', 'prep', 'verb', 'conj', 'verb', 'art', 'subs', 'conj']
# Predicted phrase boundaries: ['x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'x', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'p']
# True phrase boundaries ['x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'x', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'p']
# -
# Input clause: ['subs', 'conj', 'verb', 'subs', 'adjv', 'prep', 'art', 'subs', 'conj', 'art', 'subs', 'verb', 'prep', 'verb', 'conj', 'verb', 'art', 'subs', 'conj', 'verb']
# Predicted phrase boundaries: ['x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'x', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'p', 'x', 'p']
# True phrase boundaries ['x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'x', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'p', 'x', 'p']
# -
# Input clause: ['conj', 'verb', 'subs', 'adjv', 'prep', 'art', 'subs', 'conj', 'art', 'subs', 'verb', 'prep', 'verb', 'conj', 'verb', 'art', 'subs', 'conj', 'verb', 'subs']
# Predicted phrase boundaries: ['x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'x', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x']
# True phrase boundaries ['x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'x', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p']
# -
# Input clause: ['verb', 'subs', 'adjv', 'prep', 'art', 'subs', 'conj', 'art', 'subs', 'verb', 'prep', 'verb', 'conj', 'verb', 'art', 'subs', 'conj', 'verb', 'subs', 'prep']
# Predicted phrase boundaries: ['x', 'p', 'x', 'x', 'p', 'x', 'x', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x']
# True phrase boundaries ['x', 'p', 'x', 'x', 'p', 'x', 'x', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x']
# -
# Input clause: ['subs', 'adjv', 'prep', 'art', 'subs', 'conj', 'art', 'subs', 'verb', 'prep', 'verb', 'conj', 'verb', 'art', 'subs', 'conj', 'verb', 'subs', 'prep', 'subs']
# Predicted phrase boundaries: ['x', 'x', 'p', 'x', 'x', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'p']
# True phrase boundaries ['x', 'x', 'p', 'x', 'x', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'p']
# -
# Input clause: ['adjv', 'prep', 'art', 'subs', 'conj', 'art', 'subs', 'verb', 'prep', 'verb', 'conj', 'verb', 'art', 'subs', 'conj', 'verb', 'subs', 'prep', 'subs', 'conj']
# Predicted phrase boundaries: ['x', 'p', 'x', 'x', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'p']
# True phrase boundaries ['x', 'p', 'x', 'x', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'p']
# -
# Input clause: ['prep', 'art', 'subs', 'conj', 'art', 'subs', 'verb', 'prep', 'verb', 'conj', 'verb', 'art', 'subs', 'conj', 'verb', 'subs', 'prep', 'subs', 'conj', 'verb']
# Predicted phrase boundaries: ['x', 'x', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'p', 'x', 'p']
# True phrase boundaries ['x', 'x', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'p', 'x', 'p']
# -
# Input clause: ['art', 'subs', 'conj', 'art', 'subs', 'verb', 'prep', 'verb', 'conj', 'verb', 'art', 'subs', 'conj', 'verb', 'subs', 'prep', 'subs', 'conj', 'verb', 'prep']
# Predicted phrase boundaries: ['x', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x']
# True phrase boundaries ['x', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x']
# -
# Input clause: ['subs', 'conj', 'art', 'subs', 'verb', 'prep', 'verb', 'conj', 'verb', 'art', 'subs', 'conj', 'verb', 'subs', 'prep', 'subs', 'conj', 'verb', 'prep', 'art']
# Predicted phrase boundaries: ['x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x']
# True phrase boundaries ['x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x']
# -
# Input clause: ['conj', 'art', 'subs', 'verb', 'prep', 'verb', 'conj', 'verb', 'art', 'subs', 'conj', 'verb', 'subs', 'prep', 'subs', 'conj', 'verb', 'prep', 'art', 'subs']
# Predicted phrase boundaries: ['x', 'p', 'x', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'x', 'p']
# True phrase boundaries ['x', 'p', 'x', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'x', 'p']
# -
# Input clause: ['art', 'subs', 'verb', 'prep', 'verb', 'conj', 'verb', 'art', 'subs', 'conj', 'verb', 'subs', 'prep', 'subs', 'conj', 'verb', 'prep', 'art', 'subs', 'conj']
# Predicted phrase boundaries: ['x', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'x', 'p', 'x', 'p']
# True phrase boundaries ['x', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'x', 'p', 'x', 'p']
# -
# Input clause: ['subs', 'verb', 'prep', 'verb', 'conj', 'verb', 'art', 'subs', 'conj', 'verb', 'subs', 'prep', 'subs', 'conj', 'verb', 'prep', 'art', 'subs', 'conj', 'prep']
# Predicted phrase boundaries: ['x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'x', 'x', 'x']
# True phrase boundaries ['x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'x', 'p', 'x', 'p', 'x']
# -
# Input clause: ['verb', 'prep', 'verb', 'conj', 'verb', 'art', 'subs', 'conj', 'verb', 'subs', 'prep', 'subs', 'conj', 'verb', 'prep', 'art', 'subs', 'conj', 'prep', 'art']
# Predicted phrase boundaries: ['x', 'p', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'x', 'p', 'x', 'p', 'x', 'x']
# True phrase boundaries ['x', 'p', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'x', 'p', 'x', 'p', 'x', 'x']
# -
# Input clause: ['prep', 'verb', 'conj', 'verb', 'art', 'subs', 'conj', 'verb', 'subs', 'prep', 'subs', 'conj', 'verb', 'prep', 'art', 'subs', 'conj', 'prep', 'art', 'subs']
# Predicted phrase boundaries: ['x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'x', 'x', 'x', 'x', 'x']
# True phrase boundaries ['x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'x', 'p', 'x', 'p', 'x', 'x', 'x', 'p']
# -
# Input clause: ['verb', 'conj', 'verb', 'art', 'subs', 'conj', 'verb', 'subs', 'prep', 'subs', 'conj', 'verb', 'prep', 'art', 'subs', 'conj', 'prep', 'art', 'subs', 'prep']
# Predicted phrase boundaries: ['x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'x', 'p', 'x', 'p', 'x', 'x', 'x', 'p', 'x']
# True phrase boundaries ['x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'x', 'p', 'x', 'p', 'x', 'x', 'x', 'p', 'x']
# -
# Input clause: ['conj', 'verb', 'art', 'subs', 'conj', 'verb', 'subs', 'prep', 'subs', 'conj', 'verb', 'prep', 'art', 'subs', 'conj', 'prep', 'art', 'subs', 'prep', 'art']
# Predicted phrase boundaries: ['x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'x', 'x', 'x', 'x', 'x', 'x', 'x']
# True phrase boundaries ['x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'x', 'p', 'x', 'p', 'x', 'x', 'x', 'p', 'x', 'x']
# -
# Input clause: ['verb', 'art', 'subs', 'conj', 'verb', 'subs', 'prep', 'subs', 'conj', 'verb', 'prep', 'art', 'subs', 'conj', 'prep', 'art', 'subs', 'prep', 'art', 'subs']
# Predicted phrase boundaries: ['x', 'p', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'x', 'x', 'x', 'x', 'x', 'x', 'x', 'x', 'p']
# True phrase boundaries ['x', 'p', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'x', 'p', 'x', 'p', 'x', 'x', 'x', 'p', 'x', 'x', 'x', 'p']
# -
# Input clause: ['art', 'subs', 'conj', 'verb', 'subs', 'prep', 'subs', 'conj', 'verb', 'prep', 'art', 'subs', 'conj', 'prep', 'art', 'subs', 'prep', 'art', 'subs', 'prep']
# Predicted phrase boundaries: ['x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'x', 'x', 'x', 'x', 'x', 'x', 'x', 'x', 'x']
# True phrase boundaries ['x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'x', 'p', 'x', 'p', 'x', 'x', 'x', 'p', 'x', 'x', 'x', 'p', 'x']
# -
# Input clause: ['subs', 'conj', 'verb', 'subs', 'prep', 'subs', 'conj', 'verb', 'prep', 'art', 'subs', 'conj', 'prep', 'art', 'subs', 'prep', 'art', 'subs', 'prep', 'verb']
# Predicted phrase boundaries: ['x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'x', 'x', 'x', 'x', 'x', 'p', 'x', 'x', 'x', 'p', 'x', 'x', 'p']
# True phrase boundaries ['x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'x', 'p', 'x', 'p', 'x', 'x', 'x', 'p', 'x', 'x', 'x', 'p', 'x', 'x', 'p']
# -
# Input clause: ['conj', 'verb', 'subs', 'prep', 'subs', 'conj', 'verb', 'prep', 'art', 'subs', 'conj', 'prep', 'art', 'subs', 'prep', 'art', 'subs', 'prep', 'verb', 'prep']
# Predicted phrase boundaries: ['x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'x', 'p', 'x', 'p', 'x', 'x', 'x', 'p', 'x', 'x', 'x', 'p', 'x', 'x', 'p', 'x']
# True phrase boundaries ['x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'x', 'p', 'x', 'p', 'x', 'x', 'x', 'p', 'x', 'x', 'x', 'p', 'x', 'x', 'p', 'x']
# -
# Input clause: ['verb', 'subs', 'prep', 'subs', 'conj', 'verb', 'prep', 'art', 'subs', 'conj', 'prep', 'art', 'subs', 'prep', 'art', 'subs', 'prep', 'verb', 'prep', 'prep']
# Predicted phrase boundaries: ['x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'x', 'x', 'x', 'x', 'x', 'p', 'x', 'x', 'x', 'p', 'x', 'x', 'p', 'x', 'p', 'x']
# True phrase boundaries ['x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'x', 'p', 'x', 'p', 'x', 'x', 'x', 'p', 'x', 'x', 'x', 'p', 'x', 'x', 'p', 'x', 'x', 'p']
# -
# ...
# -
# Input clause: ['intj', 'prep', 'prep', 'conj', 'prep', 'prin', 'art', 'subs', 'art', 'prde', 'prep', 'prin', 'subs', 'conj', 'prep', 'inrg', 'verb', 'prin', 'subs', 'conj']
# Predicted phrase boundaries: ['x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'x', 'p', 'x', 'p', 'x', 'x', 'x', 'p', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p']
# True phrase boundaries ['x', 'p', 'x', 'p', 'x', 'x', 'x', 'x', 'p', 'x', 'x', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p']
# -
# Input clause: ['prep', 'prep', 'conj', 'prep', 'prin', 'art', 'subs', 'art', 'prde', 'prep', 'prin', 'subs', 'conj', 'prep', 'inrg', 'verb', 'prin', 'subs', 'conj', 'inrg']
# Predicted phrase boundaries: ['x', 'p', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'x', 'x', 'p', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p']
# True phrase boundaries ['x', 'p', 'x', 'x', 'x', 'x', 'p', 'x', 'x', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x']
# -
# Input clause: ['prep', 'conj', 'prep', 'prin', 'art', 'subs', 'art', 'prde', 'prep', 'prin', 'subs', 'conj', 'prep', 'inrg', 'verb', 'prin', 'subs', 'conj', 'inrg', 'prep']
# Predicted phrase boundaries: ['x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'x', 'p', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x']
# True phrase boundaries ['x', 'x', 'x', 'x', 'p', 'x', 'x', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x']
# -
# Input clause: ['conj', 'prep', 'prin', 'art', 'subs', 'art', 'prde', 'prep', 'prin', 'subs', 'conj', 'prep', 'inrg', 'verb', 'prin', 'subs', 'conj', 'inrg', 'prep', 'prde']
# Predicted phrase boundaries: ['x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'x', 'p']
# True phrase boundaries ['x', 'x', 'x', 'p', 'x', 'x', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'x', 'p']
# -
# Input clause: ['prep', 'prin', 'art', 'subs', 'art', 'prde', 'prep', 'prin', 'subs', 'conj', 'prep', 'inrg', 'verb', 'prin', 'subs', 'conj', 'inrg', 'prep', 'prde', 'subs']
# Predicted phrase boundaries: ['x', 'x', 'p', 'x', 'x', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'x', 'x', 'p']
# True phrase boundaries ['x', 'x', 'p', 'x', 'x', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'x', 'p', 'x', 'p']
# -
# Input clause: ['prin', 'art', 'subs', 'art', 'prde', 'prep', 'prin', 'subs', 'conj', 'prep', 'inrg', 'verb', 'prin', 'subs', 'conj', 'inrg', 'prep', 'prde', 'subs', 'prps']
# Predicted phrase boundaries: ['x', 'p', 'x', 'x', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'x', 'p', 'x', 'p', 'x', 'p']
# True phrase boundaries ['x', 'p', 'x', 'x', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'x', 'p', 'x', 'p', 'x', 'p']
# -
# Input clause: ['art', 'subs', 'art', 'prde', 'prep', 'prin', 'subs', 'conj', 'prep', 'inrg', 'verb', 'prin', 'subs', 'conj', 'inrg', 'prep', 'prde', 'subs', 'prps', 'conj']
# Predicted phrase boundaries: ['x', 'x', 'x', 'x', 'p', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p']
# True phrase boundaries ['x', 'x', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p']
# -
# Input clause: ['subs', 'art', 'prde', 'prep', 'prin', 'subs', 'conj', 'prep', 'inrg', 'verb', 'prin', 'subs', 'conj', 'inrg', 'prep', 'prde', 'subs', 'prps', 'conj', 'verb']
# Predicted phrase boundaries: ['x', 'x', 'x', 'p', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p']
# True phrase boundaries ['x', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p']
# -
# Input clause: ['art', 'prde', 'prep', 'prin', 'subs', 'conj', 'prep', 'inrg', 'verb', 'prin', 'subs', 'conj', 'inrg', 'prep', 'prde', 'subs', 'prps', 'conj', 'verb', 'prep']
# Predicted phrase boundaries: ['x', 'x', 'p', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p']
# True phrase boundaries ['x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p']
# -
# Input clause: ['prde', 'prep', 'prin', 'subs', 'conj', 'prep', 'inrg', 'verb', 'prin', 'subs', 'conj', 'inrg', 'prep', 'prde', 'subs', 'prps', 'conj', 'verb', 'prep', 'adjv']
# Predicted phrase boundaries: ['x', 'p', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p']
# True phrase boundaries ['x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p']
# -
# Input clause: ['prep', 'prin', 'subs', 'conj', 'prep', 'inrg', 'verb', 'prin', 'subs', 'conj', 'inrg', 'prep', 'prde', 'subs', 'prps', 'conj', 'verb', 'prep', 'adjv', 'prps']
# Predicted phrase boundaries: ['x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p']
# True phrase boundaries ['x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p']
# -
# Input clause: ['prin', 'subs', 'conj', 'prep', 'inrg', 'verb', 'prin', 'subs', 'conj', 'inrg', 'prep', 'prde', 'subs', 'prps', 'conj', 'verb', 'prep', 'adjv', 'prps', 'conj']
# Predicted phrase boundaries: ['x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p']
# True phrase boundaries ['x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p']
# -
# Input clause: ['subs', 'conj', 'prep', 'inrg', 'verb', 'prin', 'subs', 'conj', 'inrg', 'prep', 'prde', 'subs', 'prps', 'conj', 'verb', 'prep', 'adjv', 'prps', 'conj', 'prep']
# Predicted phrase boundaries: ['x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x']
# True phrase boundaries ['x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x']
# -
# Input clause: ['conj', 'prep', 'inrg', 'verb', 'prin', 'subs', 'conj', 'inrg', 'prep', 'prde', 'subs', 'prps', 'conj', 'verb', 'prep', 'adjv', 'prps', 'conj', 'prep', 'nmpr']
# Predicted phrase boundaries: ['x', 'p', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'p']
# True phrase boundaries ['x', 'p', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x']
# -
# Input clause: ['prep', 'inrg', 'verb', 'prin', 'subs', 'conj', 'inrg', 'prep', 'prde', 'subs', 'prps', 'conj', 'verb', 'prep', 'adjv', 'prps', 'conj', 'prep', 'nmpr', 'subs']
# Predicted phrase boundaries: ['x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'x', 'p']
# True phrase boundaries ['x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'x']
# -
# Input clause: ['inrg', 'verb', 'prin', 'subs', 'conj', 'inrg', 'prep', 'prde', 'subs', 'prps', 'conj', 'verb', 'prep', 'adjv', 'prps', 'conj', 'prep', 'nmpr', 'subs', 'art']
# Predicted phrase boundaries: ['x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'x', 'x']
# True phrase boundaries ['x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'x', 'x']
# -
# Input clause: ['verb', 'prin', 'subs', 'conj', 'inrg', 'prep', 'prde', 'subs', 'prps', 'conj', 'verb', 'prep', 'adjv', 'prps', 'conj', 'prep', 'nmpr', 'subs', 'art', 'subs']
# Predicted phrase boundaries: ['x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'x', 'x', 'x', 'p']
# True phrase boundaries ['x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'x', 'x', 'x', 'p']
# -
# Input clause: ['prin', 'subs', 'conj', 'inrg', 'prep', 'prde', 'subs', 'prps', 'conj', 'verb', 'prep', 'adjv', 'prps', 'conj', 'prep', 'nmpr', 'subs', 'art', 'subs', 'prps']
# Predicted phrase boundaries: ['x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'x', 'x', 'x', 'p', 'x', 'p']
# True phrase boundaries ['x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'x', 'x', 'x', 'p', 'x', 'p']
# -
# Input clause: ['subs', 'conj', 'inrg', 'prep', 'prde', 'subs', 'prps', 'conj', 'verb', 'prep', 'adjv', 'prps', 'conj', 'prep', 'nmpr', 'subs', 'art', 'subs', 'prps', 'verb']
# Predicted phrase boundaries: ['x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'x', 'x', 'x', 'p', 'x', 'p', 'x', 'p']
# True phrase boundaries ['x', 'p', 'x', 'p', 'x', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'x', 'x', 'x', 'p', 'x', 'p', 'x', 'p']
# -
# Input clause: ['conj', 'inrg', 'prep', 'prde', 'subs', 'prps', 'conj', 'verb', 'prep', 'adjv', 'prps', 'conj', 'prep', 'nmpr', 'subs', 'art', 'subs', 'prps', 'verb', 'conj']
# Predicted phrase boundaries: ['x', 'p', 'x', 'p', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'x', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p']
# True phrase boundaries ['x', 'p', 'x', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'x', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p']
# -
# Input clause: ['inrg', 'prep', 'prde', 'subs', 'prps', 'conj', 'verb', 'prep', 'adjv', 'prps', 'conj', 'prep', 'nmpr', 'subs', 'art', 'subs', 'prps', 'verb', 'conj', 'verb']
# Predicted phrase boundaries: ['x', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'x', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p']
# True phrase boundaries ['x', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'x', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p']
# -
# Input clause: ['prep', 'prde', 'subs', 'prps', 'conj', 'verb', 'prep', 'adjv', 'prps', 'conj', 'prep', 'nmpr', 'subs', 'art', 'subs', 'prps', 'verb', 'conj', 'verb', 'prep']
# Predicted phrase boundaries: ['x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'x', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x']
# True phrase boundaries ['x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'x', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x']
# -
# Input clause: ['prde', 'subs', 'prps', 'conj', 'verb', 'prep', 'adjv', 'prps', 'conj', 'prep', 'nmpr', 'subs', 'art', 'subs', 'prps', 'verb', 'conj', 'verb', 'prep', 'art']
# Predicted phrase boundaries: ['x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'x', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x']
# True phrase boundaries ['x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'x', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x']
# -
# Input clause: ['subs', 'prps', 'conj', 'verb', 'prep', 'adjv', 'prps', 'conj', 'prep', 'nmpr', 'subs', 'art', 'subs', 'prps', 'verb', 'conj', 'verb', 'prep', 'art', 'subs']
# Predicted phrase boundaries: ['x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'x', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'x', 'p']
# True phrase boundaries ['x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'x', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'x']
# -
# Input clause: ['prps', 'conj', 'verb', 'prep', 'adjv', 'prps', 'conj', 'prep', 'nmpr', 'subs', 'art', 'subs', 'prps', 'verb', 'conj', 'verb', 'prep', 'art', 'subs', 'conj']
# Predicted phrase boundaries: ['x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'x', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'x', 'p', 'x', 'p']
# True phrase boundaries ['x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'x', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'x', 'x']
# -
# Input clause: ['conj', 'verb', 'prep', 'adjv', 'prps', 'conj', 'prep', 'nmpr', 'subs', 'art', 'subs', 'prps', 'verb', 'conj', 'verb', 'prep', 'art', 'subs', 'conj', 'prep']
# Predicted phrase boundaries: ['x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'x', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'x', 'x', 'x']
# True phrase boundaries ['x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'x', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'x', 'x', 'x']
# -
# Input clause: ['verb', 'prep', 'adjv', 'prps', 'conj', 'prep', 'nmpr', 'subs', 'art', 'subs', 'prps', 'verb', 'conj', 'verb', 'prep', 'art', 'subs', 'conj', 'prep', 'art']
# Predicted phrase boundaries: ['x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'x', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'x', 'x', 'x', 'x']
# True phrase boundaries ['x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'x', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'x', 'x', 'x', 'x']
# -
# Input clause: ['prep', 'adjv', 'prps', 'conj', 'prep', 'nmpr', 'subs', 'art', 'subs', 'prps', 'verb', 'conj', 'verb', 'prep', 'art', 'subs', 'conj', 'prep', 'art', 'subs']
# Predicted phrase boundaries: ['x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'x', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'x', 'x', 'x', 'x', 'x', 'p']
# True phrase boundaries ['x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'x', 'x', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'p', 'x', 'x', 'x', 'x', 'x', 'x', 'x', 'p']
